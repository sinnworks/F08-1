-- %% [markdown]
-- # [MidtermHW]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [MidtermHW]    Script Date: 2023/9/11 下午 10:43:49 ******/
CREATE DATABASE [MidtermHW]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'MidternHW', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQL2022\MSSQL\DATA\MidternHW.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'MidternHW_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQL2022\MSSQL\DATA\MidternHW_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [MidtermHW] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [MidtermHW].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [MidtermHW] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [MidtermHW] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [MidtermHW] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [MidtermHW] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [MidtermHW] SET ARITHABORT OFF 
GO
ALTER DATABASE [MidtermHW] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [MidtermHW] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [MidtermHW] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [MidtermHW] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [MidtermHW] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [MidtermHW] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [MidtermHW] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [MidtermHW] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [MidtermHW] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [MidtermHW] SET  DISABLE_BROKER 
GO
ALTER DATABASE [MidtermHW] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [MidtermHW] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [MidtermHW] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [MidtermHW] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [MidtermHW] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [MidtermHW] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [MidtermHW] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [MidtermHW] SET RECOVERY FULL 
GO
ALTER DATABASE [MidtermHW] SET  MULTI_USER 
GO
ALTER DATABASE [MidtermHW] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [MidtermHW] SET DB_CHAINING OFF 
GO
ALTER DATABASE [MidtermHW] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [MidtermHW] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [MidtermHW] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [MidtermHW] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'MidtermHW', N'ON'
GO
ALTER DATABASE [MidtermHW] SET QUERY_STORE = ON
GO
ALTER DATABASE [MidtermHW] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [Hw]

-- %%
USE [MidtermHW]
GO

-- %%
/****** Object:  User [Hw]    Script Date: 2023/9/11 下午 10:43:50 ******/
CREATE USER [Hw] WITHOUT LOGIN WITH DEFAULT_SCHEMA=[dbo]
GO

-- %%
ALTER ROLE [db_owner] ADD MEMBER [Hw]
GO

-- %% [markdown]
-- # [dbo].[Categories]

-- %%
/****** Object:  Table [dbo].[Categories]    Script Date: 2023/9/11 下午 10:43:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Categories](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nvarchar](30) NOT NULL,
	[DisplayOrder] [int] NOT NULL,
 CONSTRAINT [PK_Categories] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ContactUs]

-- %%
/****** Object:  Table [dbo].[ContactUs]    Script Date: 2023/9/11 下午 10:43:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ContactUs](
	[Id] [int] NOT NULL,
	[Name] [nvarchar](50) NOT NULL,
	[Gender] [nchar](10) NOT NULL,
	[Suggestion] [nvarchar](max) NOT NULL,
	[Image] [varbinary](max) NULL,
	[PhoneNumber] [char](10) NOT NULL,
 CONSTRAINT [PK_ContactUs] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Members]

-- %%
/****** Object:  Table [dbo].[Members]    Script Date: 2023/9/11 下午 10:43:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Members](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nvarchar](50) NOT NULL,
	[Gender] [nchar](10) NOT NULL,
	[BirthDate] [date] NOT NULL,
	[PhoneNumber] [char](10) NOT NULL,
	[Email] [nchar](50) NOT NULL,
	[Account] [nchar](50) NOT NULL,
	[Password] [nchar](50) NOT NULL,
	[Address] [nvarchar](max) NOT NULL,
 CONSTRAINT [PK_Members] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[OrderItems]

-- %%
/****** Object:  Table [dbo].[OrderItems]    Script Date: 2023/9/11 下午 10:43:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[OrderItems](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[OrderId] [int] NOT NULL,
	[ProductId] [int] NOT NULL,
	[ProductName] [nvarchar](max) NOT NULL,
	[Quantity] [int] NOT NULL,
	[TakeOut] [nvarchar](50) NOT NULL,
	[SubTotal] [int] NOT NULL,
	[UnitPrice] [int] NOT NULL,
 CONSTRAINT [PK_Table_1] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Orders]

-- %%
/****** Object:  Table [dbo].[Orders]    Script Date: 2023/9/11 下午 10:43:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Orders](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[OrderTime] [date] NOT NULL,
	[MemberId] [int] NOT NULL,
	[Total] [int] NOT NULL,
 CONSTRAINT [PK_Orders] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Products]

-- %%
/****** Object:  Table [dbo].[Products]    Script Date: 2023/9/11 下午 10:43:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Products](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nvarchar](50) NOT NULL,
	[UnitPrice] [int] NOT NULL,
	[CategoryId] [int] NOT NULL,
 CONSTRAINT [PK_Products] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ShoppingCarts]

-- %%
/****** Object:  Table [dbo].[ShoppingCarts]    Script Date: 2023/9/11 下午 10:43:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ShoppingCarts](
	[Id] [int] NOT NULL,
	[Quantity] [int] NOT NULL,
	[UnitPrice] [int] NOT NULL,
	[TotalPrice] [int] NOT NULL,
	[ProductId] [int] NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [IX_Members]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [IX_Members]    Script Date: 2023/9/11 下午 10:43:50 ******/
CREATE UNIQUE NONCLUSTERED INDEX [IX_Members] ON [dbo].[Members]
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, DROP_EXISTING = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_OrderItems_Orders]

-- %%
ALTER TABLE [dbo].[OrderItems]  WITH CHECK ADD  CONSTRAINT [FK_OrderItems_Orders] FOREIGN KEY([OrderId])
REFERENCES [dbo].[Orders] ([Id])
GO
ALTER TABLE [dbo].[OrderItems] CHECK CONSTRAINT [FK_OrderItems_Orders]
GO

-- %% [markdown]
-- # [FK_OrderItems_Products]

-- %%
ALTER TABLE [dbo].[OrderItems]  WITH CHECK ADD  CONSTRAINT [FK_OrderItems_Products] FOREIGN KEY([ProductId])
REFERENCES [dbo].[Products] ([Id])
GO
ALTER TABLE [dbo].[OrderItems] CHECK CONSTRAINT [FK_OrderItems_Products]
GO

-- %% [markdown]
-- # [FK_Orders_Members]

-- %%
ALTER TABLE [dbo].[Orders]  WITH CHECK ADD  CONSTRAINT [FK_Orders_Members] FOREIGN KEY([MemberId])
REFERENCES [dbo].[Members] ([Id])
GO
ALTER TABLE [dbo].[Orders] CHECK CONSTRAINT [FK_Orders_Members]
GO

-- %% [markdown]
-- # [FK_Products_Categories]

-- %%
ALTER TABLE [dbo].[Products]  WITH CHECK ADD  CONSTRAINT [FK_Products_Categories] FOREIGN KEY([CategoryId])
REFERENCES [dbo].[Categories] ([Id])
GO
ALTER TABLE [dbo].[Products] CHECK CONSTRAINT [FK_Products_Categories]
GO

-- %% [markdown]
-- # [dbo].[SelectProducts]

-- %%
/****** Object:  StoredProcedure [dbo].[SelectProducts]    Script Date: 2023/9/11 下午 10:43:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SelectProducts]
(
@CategoryId INT=NULL
)
AS
BEGIN;
	SET NOCOUNT ON;

	SELECT P.Id as ProductId, P.Name as ProductName, C.Name as CategoryName
	FROM Products as P
	Inner Join Categories as C on C.Id = P.CategoryId
	WHERE (@CategoryId IS NULL OR P.CategoryId = @CategoryId)
	ORDER BY C.DisplayOrder

	SET NOCOUNT OFF;

END;
GO

-- %% [markdown]
-- # [MidtermHW]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [MidtermHW] SET  READ_WRITE 
GO
